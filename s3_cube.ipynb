# %%
import xarray as xr
from odc.geo.geobox import GeoBox
from odc.geo.geom import Geometry
from odc.geo.xr import crop, xr_reproject
from shapely.geometry import box
from typing import List, Optional, Tuple
import rioxarray as riox
import s3fs
from datetime import datetime
import pandas as pd
import re

import dask.distributed
import arraylake

def extract_years_and_set_time_if_missing_coords(filenames, da, year_range=(1990, 2100)):
    """
    Extract years from filenames and set them as time coordinates
    only if the 'time' dimension exists but does not have coordinates.
    
    Parameters:
        filenames (list of str): List of filenames containing year information.
        da (xarray.DataArray or xarray.Dataset): DataArray or Dataset to update.
        year_range (tuple): Range of valid years (default: 1990 to 2100).
    
    Returns:
        xarray.DataArray or xarray.Dataset: Updated xarray object with time coordinates set.
    """
    # Check if 'time' dimension exists and has no coordinates
    if "time" in da.dims and "time" not in da.coords:
        # Compile regex for extracting 4-digit years
        year_regex = re.compile(r"(19[9][0-9]|20[0-9]{2}|2100)")

        # Extract years from filenames
        years = []
        for filename in filenames:
            match = year_regex.search(filename)
            if match:
                year = int(match.group())
                if year_range[0] <= year <= year_range[1]:
                    years.append(year)
                else:
                    raise ValueError(f"Year {year} in file '{filename}' is out of the specified range.")
            else:
                raise ValueError(f"No valid year found in filename: {filename}")

        # Convert years to pd.Timestamp
        time_coords = pd.to_datetime([f"{year}-01-01" for year in years])

        # Assign time coordinates
        da = da.assign_coords(time=time_coords)
    
    return da


def build_datacube(
    raster_files: List[str],
    bounds: List[float],
    varname: str,
    resolution: float = 0.009,
    src_crs: str = "EPSG:4326",
    dst_crs: str = "EPSG:4326",
    resampling: str = "bilinear",
    startyear: int = 2000,
    endyear: int = 2020,
    time_frequency_years: int = 5
) -> xr.DataArray:
    """
    Build a datacube from a list of raster files, crop to bounds, and save to zarr format.
    
    Args:
        raster_files: List of paths to raster files to combine
        bounds: List of [xmin, ymin, xmax, ymax] coordinates
        varname: Name of the output variable
        resolution: Output resolution in degrees (default: 0.009)
        src_crs: Source coordinate reference system (default: "EPSG:4326")
        dst_crs: Destination coordinate reference system (default: "EPSG:4326") 
        resampling: Resampling method for reprojection (default: "bilinear")
        startyear: Start year for resampling (default: 2000)
        endyear: End year for resampling (default: 2020)
        time_frequency_years: Frequency of resampling in years (default: 5)
    Returns:
        xr.DataArray: The processed datacube
        
    Example:
        >>> raster_files = ["data/gdp/gdp1990.tif", "data/gdp/gdp2000.tif"]
        >>> bounds = [17.58, -35.00, 21.38, -32.23]
        >>> da = build_datacube(
        ...     raster_files=raster_files,
        ...     bounds=bounds, 
        ...     varname="gdp"
        ... )
    """
    

    #TODO extend to accomodate multiple bands/variables
    rasters = []
    
    # Check if files are on S3 or local and open accordingly
    for file in raster_files:
        if file.startswith("s3://"):
            # Open file from S3
            fs = s3fs.S3FileSystem()
            with fs.open(file) as infile:
                rasters.append(riox.open_rasterio(infile, chunks='auto'))
        else:
            # Open local file
            rasters.append(riox.open_rasterio(file, chunks='auto'))
    
    # Combine rasters along the time dimension
    combined = xr.concat(rasters, dim="time").squeeze()
    #set time coords
    combined = extract_years_and_set_time_if_missing_coords(raster_files, combined)

    # Set CRS
    if combined.rio.crs is not None:
        combined = combined.odc.assign_crs(combined.rio.crs)
    else:
        combined = combined.odc.assign_crs(src_crs)

    # Create template
    template = GeoBox.from_bbox(bounds, crs=dst_crs, resolution=resolution)
    bbox = box(*template.boundingbox)
    geom = Geometry(bbox, dst_crs)

    # Crop to box
    combined = crop(combined, geom)

    # Reproject dataset
    da = xr_reproject(
        combined,
        how=template,
        resampling=resampling,
    )
    
    # Name the dataarray
    da = da.rename(varname)
    #if there is a a time dim resample 
    if "time" in da.dims:
        start_date = datetime(startyear,1,1)
        end_date = datetime(endyear,12,31)
        time_frequency_years = 5

        # Interpolate
        dseqn = pd.date_range(
            start=start_date,
            end=end_date,
            freq=pd.DateOffset(years=time_frequency_years),
            inclusive='left'  # Exclude end_date
        )
        da = da.interp(
            time=dseqn,
            method="linear",
            assume_sorted=True,
            )

    return da

# %%
# Initialize dask client
client_da = dask.distributed.Client()
# Out:
# /home/sagemaker-user/.conda/envs/pangeo/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41329 instead
#   warnings.warn(

# %%
#files to cube
raster_files = ["s3://sagemaker-us-west-2-482277551691/glenn/hm_data/gdp/gdp1990.tif",
                "s3://sagemaker-us-west-2-482277551691/glenn/hm_data/gdp/gdp2000.tif",
                "s3://sagemaker-us-west-2-482277551691/glenn/hm_data/gdp/gdp2010.tif",
                "s3://sagemaker-us-west-2-482277551691/glenn/hm_data/gdp/gdp2020.tif",
                "s3://sagemaker-us-west-2-482277551691/glenn/hm_data/gdp/gdp2030.tif"]
#boundiung box
bounds = [17.58, -35.00, 21.38, -32.23]
#chunks
chunk_shape = (100,100)

#build cube
da = build_datacube(
    raster_files=raster_files,
    bounds=bounds,
    resampling='nearest',
    varname="gdp",
)

#chunk
# Initialize chunks dictionary with default values
chunks = {dim: -1 for dim in da.dims if dim not in ["time", "latitude", "longitude"]}

# Set chunk sizes for specific dimensions
if "time" in da.dims:
    chunks["time"] = 1
if "latitude" in da.dims:
    chunks["latitude"] = chunk_shape[0]
if "longitude" in da.dims:
    chunks["longitude"] = chunk_shape[1]

# Create encoding dictionary
encoding = {}
for dim, chunk_size in chunks.items():
    encoding[dim] = {"chunks": chunk_size}
        
# Apply chunking
ds = da.chunk(chunks).to_dataset()

# %%
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:      (latitude: 308, longitude: 423, time: 5)
# Coordinates:
#     band         int64 8B 1
#   * latitude     (latitude) float64 2kB -32.23 -32.24 -32.25 ... -34.99 -35.0
#   * longitude    (longitude) float64 3kB 17.58 17.59 17.6 ... 21.36 21.37 21.38
#     spatial_ref  int32 4B 4326
#   * time         (time) datetime64[ns] 40B 2000-01-01 2005-01-01 ... 2020-01-01
# Data variables:
#     gdp          (time, latitude, longitude) float32 3MB dask.array<chunksize=(1, 100, 100), meta=np.ndarray>

# %%
#local write
#outfile = 'test.zarr'
# Write to zarr
#da.to_zarr(outfile, mode="w",encoding=encoding)

#arraylake write
# Instantiate the Arraylake client
client_ar = arraylake.Client()

# Checkout the repo
repo = client_ar.get_repo("the-nature-conservancy/hm-forecasting")
#repo = client.get_repo("the-nature-conservancy/gmoncrieff-scratch")

# write
ds.to_zarr(repo.store, group="gdp-test", zarr_version=3,encoding=encoding)

# Make your first commit
repo.commit('commit test gdp cube')
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/api_utils.py:348, in handle_response(response)
#     347 try:
# --> 348     response.raise_for_status()
#     349 except httpx.RequestError as exc:
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/httpx/_models.py:761, in Response.raise_for_status(self)
#     760 message = message.format(self, error_type=error_type)
# --> 761 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '500 Internal Server Error' for url 'https://api.earthmover.io/repos/the-nature-conservancy/hm-forecasting/contents/metadata/_bulk_set?session_id=42946ceb0aa14b029d366fc248f9bffe&base_commit='
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/500
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 15
#      11 repo = client_ar.get_repo("the-nature-conservancy/hm-forecasting")
#      12 #repo = client.get_repo("the-nature-conservancy/gmoncrieff-scratch")
#      13
#      14 # write
# ---> 15 ds.to_zarr(repo.store, group="gdp-test", zarr_version=3,encoding=encoding)
#      17 # Make your first commit
#      18 repo.commit('commit test gdp cube')
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/core/dataset.py:2548, in Dataset.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version, write_empty_chunks, chunkmanager_store_kwargs)
#    2403 """Write dataset contents to a zarr group.
#    2404
#    2405 Zarr chunks are determined in the following way:
#    (...)
#    2544     The I/O user guide, with more details and examples.
#    2545 """
#    2546 from xarray.backends.api import to_zarr
# -> 2548 return to_zarr(  # type: ignore[call-overload,misc]
#    2549     self,
#    2550     store=store,
#    2551     chunk_store=chunk_store,
#    2552     storage_options=storage_options,
#    2553     mode=mode,
#    2554     synchronizer=synchronizer,
#    2555     group=group,
#    2556     encoding=encoding,
#    2557     compute=compute,
#    2558     consolidated=consolidated,
#    2559     append_dim=append_dim,
#    2560     region=region,
#    2561     safe_chunks=safe_chunks,
#    2562     zarr_version=zarr_version,
#    2563     write_empty_chunks=write_empty_chunks,
#    2564     chunkmanager_store_kwargs=chunkmanager_store_kwargs,
#    2565 )
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/backends/api.py:1697, in to_zarr(dataset, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version, write_empty_chunks, chunkmanager_store_kwargs)
#    1695 writer = ArrayWriter()
#    1696 # TODO: figure out how to properly handle unlimited_dims
# -> 1697 dump_to_store(dataset, zstore, writer, encoding=encoding)
#    1698 writes = writer.sync(
#    1699     compute=compute, chunkmanager_store_kwargs=chunkmanager_store_kwargs
#    1700 )
#    1702 if compute:
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/backends/api.py:1384, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1381 if encoder:
#    1382     variables, attrs = encoder(variables, attrs)
# -> 1384 store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/backends/zarr.py:726, in ZarrStore.store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     723 else:
#     724     variables_to_set = variables_encoded
# --> 726 self.set_variables(
#     727     variables_to_set, check_encoding_set, writer, unlimited_dims=unlimited_dims
#     728 )
#     729 if self._consolidate_on_close:
#     730     zarr.consolidate_metadata(self.zarr_group.store)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/backends/zarr.py:837, in ZarrStore.set_variables(self, variables, check_encoding_set, writer, unlimited_dims)
#     828             encoding["write_empty_chunks"] = self._write_empty
#     830     zarr_array = self.zarr_group.create(
#     831         name,
#     832         shape=shape,
#    (...)
#     835         **encoding,
#     836     )
# --> 837     zarr_array = _put_attrs(zarr_array, encoded_attrs)
#     839 write_region = self._write_region if self._write_region is not None else {}
#     840 write_region = {dim: write_region.get(dim, slice(None)) for dim in dims}
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/xarray/backends/zarr.py:396, in _put_attrs(zarr_obj, attrs)
#     394 """Raise a more informative error message for invalid attrs."""
#     395 try:
# --> 396     zarr_obj.attrs.put(attrs)
#     397 except TypeError as e:
#     398     raise TypeError("Invalid attribute in Dataset.attrs.") from e
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/zarr/attrs.py:126, in Attributes.put(self, d)
#     124     self._write_op(self._put_nosync, d)
#     125 else:
# --> 126     self._write_op(self._put_nosync, dict(attributes=d))
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/zarr/attrs.py:83, in Attributes._write_op(self, f, *args, **kwargs)
#      81 # synchronization
#      82 if self.synchronizer is None:
# ---> 83     return f(*args, **kwargs)
#      84 else:
#      85     with self.synchronizer[self.key]:
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/zarr/attrs.py:169, in Attributes._put_nosync(self, d)
#     167 except KeyError:
#     168     meta = d
# --> 169 self.store[self.key] = json_dumps(meta)
#     170 if self.cache:
#     171     self._cached_asdict = d["attributes"]
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:2197, in ArraylakeStore.__setitem__(self, key, value)
#    2195         raise KeyError("Cannot set zarr.json")
#    2196     doc = json.loads(value)
# -> 2197     return self._repo._set_doc(key, content=doc)
#    2198 else:
#    2199     raise KeyError(f"unexpected key: {key}")
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:1794, in Repo._set_doc(self, path, content)
#    1793 def _set_doc(self, path: Path, *, content: dict) -> None:
# -> 1794     return self._synchronize(self._arepo._set_doc, path, content=content)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:1659, in Repo._synchronize(self, method, *args, **kwargs)
#    1655 @functools.wraps(method)
#    1656 def wrap(*args, **kwargs):
#    1657     return sync(method, *args, **kwargs)
# -> 1659 return wrap(*args, **kwargs)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:1657, in Repo._synchronize.<locals>.wrap(*args, **kwargs)
#    1655 @functools.wraps(method)
#    1656 def wrap(*args, **kwargs):
# -> 1657     return sync(method, *args, **kwargs)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/asyn.py:188, in sync(func, timeout, *args, **kwargs)
#     185 return_result = result[0]
#     186 if isinstance(return_result, BaseException):
#     187     # note: fsspec has special handling for asyncio.TimeoutError; here we just raise it
# --> 188     raise return_result
#     189 else:
#     190     return return_result
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/asyn.py:135, in _runner(event, coro, result, timeout)
#     133     coro = asyncio.wait_for(coro, timeout=timeout)
#     134 try:
# --> 135     result[0] = await coro
#     136 except Exception as ex:
#     137     result[0] = ex
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:916, in AsyncRepo._set_doc(self, path, content)
#     905 @_write_op
#     906 async def _set_doc(self, path: Path, *, content: dict) -> None:
#     907     """Write a single document to the metastore
#     908
#     909     Parameters
#    (...)
#     914         Document contents
#     915     """
# --> 916     await self._set_docs({path: content})
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/repo.py:927, in AsyncRepo._set_docs(self, items)
#     918 @_write_op
#     919 async def _set_docs(self, items: Mapping[Path, dict]) -> None:
#     920     """Write multiple documents to the metastore
#     921
#     922     Parameters
#    (...)
#     925         Mapping where the keys are document paths and values are documents in the form of dictionaries.
#     926     """
# --> 927     await self.db.add_docs(items, collection=metadata_collection, session_id=self.session.id, base_commit=self.session.base_commit)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/metastore/http_metastore.py:461, in HttpMetastoreDatabase.add_docs(self, items, collection, session_id, base_commit)
#     457 async def add_docs(
#     458     self, items: Mapping[Path, Mapping[str, Any]], *, collection: CollectionName, session_id: SessionID, base_commit: CommitID | None
#     459 ) -> None:
#     460     docs = [BulkCreateDocBody(session_id=session_id, content=content, path=path) for path, content in items.items()]
# --> 461     await async_gather(
#     462         *[
#     463             self._add_docs(docs=batch, collection=collection, session_id=session_id, base_commit=base_commit)
#     464             for batch in chunks(docs, int(config.get("async.batch_size")))
#     465         ]
#     466     )
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/asyn.py:112, in async_gather(concurrency, return_exceptions, *coros)
#     109         async with semaphore:
#     110             return await coro
# --> 112     results = await asyncio.gather(*(sem_coro(c) for c in coros), return_exceptions=return_exceptions)
#     113 else:
#     114     results = await asyncio.gather(*coros, return_exceptions=return_exceptions)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/asyn.py:110, in async_gather.<locals>.sem_coro(coro)
#     108 async def sem_coro(coro):
#     109     async with semaphore:
# --> 110         return await coro
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/repos/v1/metastore/http_metastore.py:455, in HttpMetastoreDatabase._add_docs(self, docs, collection, session_id, base_commit)
#     453 content = ADD_DOCS_ADAPTER.dump_json(list(docs))
#     454 response = await self._request("PUT", f"{self._repo_path}/contents/{collection}/_bulk_set", content=content, params=params)
# --> 455 handle_response(response)
#
# File ~/.conda/envs/pangeo/lib/python3.11/site-packages/arraylake/api_utils.py:360, in handle_response(response)
#     358     raise ValueError(response.json()["detail"])
#     359 else:
# --> 360     raise ValueError(f"Error response {exc.response.status_code} while requesting {exc.request.url!r}. {response}: {response.text}")
#
# ValueError: Error response 500 while requesting URL('https://api.earthmover.io/repos/the-nature-conservancy/hm-forecasting/contents/metadata/_bulk_set?session_id=42946ceb0aa14b029d366fc248f9bffe&base_commit='). <Response [500 Internal Server Error]>:
